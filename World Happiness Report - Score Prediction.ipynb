# %% [markdown]
# # World Happines Report - Regression
#
# The World Happiness Report is a landmark survey of the state of global happiness. This report reviews the state of happiness in the world today and show how the new science of happiness explains personal and national variations in happiness. The happiness scores and rankings use data from the Gallup World Poll. The scores are based on answers to the main life evaluation question asked in the poll.

# %% [markdown]
# ## About the data
#
# - Country-Country name
# - Region- Region in which the country was categorized.
# - Happiness Rank - Classification of the country in a given year.
# - Happiness Score
# - Economy - Quantification of economic power.
# - Government Trust - A quantification of people's perceived trust in their governments.
# - Generosity- Estimated numerical value based on the perception of generosity experienced by respondents in their country.
# - Social Support- Metric that estimates people's satisfaction with their friends and family.
# - Freedom- Perception of quantified freedom.

# %% [markdown]
# ### Importing the data

# %%
import pandas as pd
import numpy as np


df = pd.read_csv(r'C:\Users\User\Desktop\Projects\happiness_score_dataset.csv')
df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
df.tail()
# Out:
#      Country                           Region  Happiness Rank  \
# 153   Rwanda               Sub-Saharan Africa             154
# 154    Benin               Sub-Saharan Africa             155
# 155    Syria  Middle East and Northern Africa             156
# 156  Burundi               Sub-Saharan Africa             157
# 157     Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 153            3.465         0.03464                   0.22208  0.77370
# 154            3.340         0.03656                   0.28665  0.35386
# 155            3.006         0.05015                   0.66320  0.47489
# 156            2.905         0.08658                   0.01530  0.41587
# 157            2.839         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 153                   0.42864  0.59201                        0.55191
# ...

# %%
df.shape
# Out:
# (158, 12)

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %%
df.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %% [markdown]
# - Mean happiness score is 5.3
# - Mean economy is 0.84
# - Mean Life expectency is 0.63

# %%
df.describe(include=['O'])
# Out:
#        Country              Region
# count      158                 158
# unique     158                  10
# top      Qatar  Sub-Saharan Africa
# freq         1                  40

# %% [markdown]
# - There are 10 different regions considered in the dataset
# - Sub-Saharan Africa consists of majority countries (40)

# %%
df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %% [markdown]
# No Null Values in the dataset

# %% [markdown]
# #### Renaming the data columns

# %%
df.columns=['country', 'region', 'happiness_rank', 'happiness_score', 'standard_error', 'economy', 'family', 'health', 'freedom', 'trust','generosity', 'dystopia_residual']

# %% [markdown]
# ## EDA

# %% [markdown]
# ### Target Variable - Happiness Score

# %%
import matplotlib.pyplot as plt
from matplotlib import pyplot
import seaborn as sns

# %% [markdown]
# #### Target Variable

# %%
plt.figure(figsize=(10,7))
sns.distplot(df['happiness_score'], bins=50, kde=True, hist_kws=dict(edgecolor='w'), color='b')
plt.xlabel('Happiness Score', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.title('Distribution of Happiness Score', fontsize=15)
plt.show()

# %% [markdown]
# It is visible that most of the happiness_score values are between 5 and 5.5.

# %% [markdown]
# ### Regions

# %%
df.region.value_counts()
# Out:
# Sub-Saharan Africa                 40
# Central and Eastern Europe         29
# Latin America and Caribbean        22
# Western Europe                     21
# Middle East and Northern Africa    20
# Southeastern Asia                   9
# Southern Asia                       7
# Eastern Asia                        6
# North America                       2
# Australia and New Zealand           2
# Name: region, dtype: int64

# %%
ser1= df.region.value_counts()

plt.figure(figsize=(8 ,8))
plt.pie( x = ser1.values , autopct = '%1.3f%%' )
plt.legend(labels=df['region'].value_counts().index, loc="best",bbox_to_anchor=(1, 0.25, 0.5, 0.5))
plt.tight_layout()

# %% [markdown]
# Sub-Saharan has majority of countries, followed by Central and Eastern Europe

# %% [markdown]
# ### Correlating Variables - Happiness Vs Region

# %% [markdown]
# #### Mean Happiness score among Regions

# %%
df_region=df.groupby('region').mean().sort_values(by='happiness_score', ascending=False).reset_index()

# %%
plt.figure(figsize=(10,7))
sns.barplot(x='region', y='happiness_score', data=df_region, palette='rainbow')
plt.xlabel('Region', fontsize=14)
plt.ylabel('Happiness Rank', fontsize=14)
plt.xticks(rotation=90)
plt.title('Mean Happiness Score Versus Regions\n', fontsize=18)
plt.show()

# %% [markdown]
# It can be seen that the highest mean happiness score among the regions is related to Australia and New Zealand

# %% [markdown]
# #### Happiness Score distribution among regions

# %%
plt.figure(figsize=(10,7))
sns.boxplot(x='region',y='happiness_score',data=df,palette='Dark2')
plt.xlabel('Region', fontsize=14)
plt.ylabel('Happiness Rank', fontsize=14)
plt.xticks(rotation=90,fontsize=12)
plt.yticks(fontsize=12)
plt.title('Distribution Of Happiness Score In Different Regions\n', fontsize=18)
plt.show()

# %% [markdown]
# Happiness Score Varies across Regions, hence the variable plays a very important role in determining

# %% [markdown]
# #### Countries with highest happiness score

# %%
df_country = df.groupby('country').mean().sort_values(by='happiness_score', ascending=False).reset_index().head(10)

# %%
plt.figure(figsize=(10,10))
plt.pie(x=df_country['happiness_score'], labels= df_country['country'], autopct='%1.2f%%', pctdistance=0.6,labeldistance=1.1,shadow=True, colors=['limegreen', 'deeppink','cyan','pink', 'teal', 'lime','paleturquoise', 'mediumpurple','violet','royalblue'], textprops={'fontsize':14}, explode=(0.2,0,0,0,0,0,0,0,0,0))
plt.title('Top 10 Countries With The Highest Mean Happiness Scores', fontsize=18)
plt.show()

# %% [markdown]
# It can be seen that the highest mean happiness score among the countries is related to Denmark.

# %% [markdown]
# ### Correlating Variables - Happiness, Economy, Family, Health, Freedom

# %%
n=sns.PairGrid(df, x_vars=['happiness_score','economy','family','health','freedom'],y_vars=['happiness_score','economy','family','health','freedom'],height=2, aspect=1.2)
n.map_upper(plt.scatter,color='teal')
n.map_diag(sns.distplot,color='lime')
n.map_lower(sns.regplot,color='royalblue')
plt.suptitle('Relationship Between Happiness Score, Economy, Family, Health And Freedom',y=1.05,fontsize=14)
plt.show()

# %% [markdown]
# - The variables Health, Family and Economy behave very linearly with the target variable Happiness Score
# - The variables Freedom and Happiness score are almost normally distributed

# %% [markdown]
# ### Correlating Variables - Happiness, Trust, Generosity, Dystopia Residual

# %%
n=sns.PairGrid(df, x_vars=['happiness_score', 'trust','generosity', 'dystopia_residual'],y_vars=['happiness_score', 'trust','generosity', 'dystopia_residual'],height=2, aspect=1.2)
n.map_upper(plt.scatter,color='teal')
n.map_diag(sns.distplot,color='lime')
n.map_lower(sns.regplot,color='royalblue')
plt.suptitle('Relationship Between Happiness Score, Economy, Family, Health And Freedom',y=1.05,fontsize=14)
plt.show()

# %% [markdown]
# - None of the above behave very linearly with Happiness Score
# - The variables Generosity and Dystopia are normally distributed

# %% [markdown]
# ### Correlating Variables - Happiness and Economy

# %%
g = sns.lmplot(x="economy", y="happiness_score", data=df, scatter=False, hue='region', col="region", 
               legend=False, height=3, col_wrap=2)

# %% [markdown]
# Except for the Regions North America and Australia and Newzeland, the variable happiness and economy behave very linearly
#
# A rise in the economy is seen to boost the happiness score as well

# %%
g = sns.lmplot(x="trust", y="happiness_score", data=df, scatter=False, hue='region', col="region", 
               legend=False, height=3, col_wrap=2)

# %% [markdown]
# In majority regions a gain in trust does not result in an increase in happiness

# %%
g = sns.lmplot(x="freedom", y="happiness_score", data=df, scatter=False, hue='region', col="region", 
               legend=False, height=3, col_wrap=2)

# %%
g = sns.lmplot(x="health", y="happiness_score", data=df, scatter=False, hue='region', col="region", 
               legend=False, height=3, col_wrap=2)

# %% [markdown]
# Except for the Regions Sub Saharan Africa, Central Eastern Europe and Australia and Newzeland, the variable happiness and health behave very linearly
#
# A rise in the Life Expectency is seen to boost the happiness score as well

# %%
correlation = df.corr()
plt.figure(figsize=(8,5))
sns.heatmap(correlation, annot= True, linewidths=0.5, linecolor="white", fmt= '.2f')

# %%
plt.figure(figsize=(10,7))
df.corr()['happiness_score'].sort_values(ascending=False).drop(['happiness_score']).plot(kind='bar',color='c')
plt.xlabel('Feature',fontsize=14)
plt.ylabel('Correlation with Happiness Score',fontsize=14)
plt.title('Correlation of Features with Happiness Score',fontsize=18)
plt.show()

# %% [markdown]
# Happiness Rank correelates highly negatively with the target variable and hence it needs to be dropped

# %%
df = df.drop(['happiness_rank'], axis=1)

# %% [markdown]
# The name of the country does not contribute to the redictions hence it is safe to drop that column too

# %%
df = df.drop(['country'], axis=1)

# %%
df.isnull().sum()
# Out:
# region               0
# happiness_score      0
# standard_error       0
# economy              0
# family               0
# health               0
# freedom              0
# trust                0
# generosity           0
# dystopia_residual    0
# dtype: int64

# %% [markdown]
# ### Encoding

# %%
le2=LabelEncoder()
le2.fit(df['region'])
df['region']=le2.transform(df['region'])

# %%
df.skew()
# Out:
# region              -0.116119
# happiness_score      0.097769
# standard_error       1.983439
# economy             -0.317575
# family              -1.006893
# health              -0.705328
# freedom             -0.413462
# trust                1.385463
# generosity           1.001961
# dystopia_residual   -0.238911
# dtype: float64

# %%
for col in df.columns:
    if df.skew().loc[col]>0.75:
        df[col]=np.log1p(df[col])

# %%
df.skew()
# Out:
# region              -0.116119
# happiness_score      0.097769
# standard_error       1.890608
# economy             -0.317575
# family              -1.006893
# health              -0.705328
# freedom             -0.413462
# trust                1.180922
# generosity           0.650767
# dystopia_residual   -0.238911
# dtype: float64

# %%
x = df.drop(columns=['happiness_score'])
y = df[['happiness_score']]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train,y_test = train_test_split(x,y,test_size=.20,random_state=55)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn import linear_model
max_r_score=0
for r_state in range(42,100):
    x_train,x_test,y_train,y_test = train_test_split(x,y,random_state = r_state, test_size=0.20)
    regr = linear_model.LinearRegression()
    regr.fit(x_train,y_train)
    y_pred = regr.predict(x_test)
    r2_scr=r2_score(y_test,y_pred)
    if r2_scr>max_r_score:
        max_r_score=r2_scr
        final_r_state=r_state
print('max r2 score corresponding to', final_r_state, 'is', max_r_score)
# Out:
# max r2 score corresponding to 81 is 0.9999689235042756

# %%
x_train, x_test, y_train,y_test = train_test_split(x,y,test_size=.20,random_state=81)

# %% [markdown]
# ## Lasso Regression

# %%
from sklearn.model_selection import GridSearchCV

# %%
from sklearn.model_selection import cross_val_score

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.linear_model import Lasso

parameters = {'alpha':[.0001, .001, .01, .1, 1, 10]}
ls = Lasso()
clf = GridSearchCV(ls,parameters)
clf.fit(x_train,y_train)

print(clf.best_params_)
# Out:
# {'alpha': 0.0001}

# %%
ls = Lasso(alpha=0.0001)
ls.fit(x_train,y_train)
ls.score(x_train,y_train)
pred_ls = ls.predict(x_test)

lss = r2_score(y_test,pred_ls)
print('R2 Score:',lss*100)

lsscore = cross_val_score(ls,x,y,cv=5)
lsc = lsscore.mean() 
print('Cross Val Score:',lsc*100)
# Out:
# R2 Score: 99.99696089666695
# Cross Val Score: 99.75741088046219

# %%
print('Error:')

print('Mean Absolute Error:',mean_absolute_error(y_test,pred_ls))
print('Mean Squared Error:',mean_squared_error(y_test,pred_ls))
print('Root Mean Square Error:',np.sqrt(mean_squared_error(y_test,pred_ls)))
# Out:
# Error:
# Mean Absolute Error: 0.005410933314571875
# Mean Squared Error: 4.160126505211021e-05
# Root Mean Square Error: 0.006449904266894991

# %%
plt.figure(figsize=(8,6))
plt.scatter(x=y_test, y=pred_ls, color='r')
plt.plot(y_test,y_test, color='b')
plt.xlabel('Actual Happiness Score',fontsize=14)
plt.ylabel('Predicted Happiness Score',fontsize=14)
plt.title('Lasso Regression',fontsize=18)
plt.show()

# %% [markdown]
# ## Ridge Regression

# %%
from sklearn.linear_model import Ridge

parameters = {'alpha':[.0001, .001, .01, .1, 1, 10]}
rd = Lasso()
clf = GridSearchCV(rd,parameters)
clf.fit(x_train,y_train)

print(clf.best_params_)
# Out:
# {'alpha': 0.0001}

# %%
rd = Ridge(alpha=0.0001)
rd.fit(x_train,y_train)
rd.score(x_train,y_train)
pred_rd = rd.predict(x_test)

rds = r2_score(y_test,pred_rd)
print('R2 Score:',rds*100)

rdscore = cross_val_score(rd,x,y,cv=5)
rdc = rdscore.mean() 
print('Cross Val Score:',rdc*100)
# Out:
# R2 Score: 99.99689476482747
# Cross Val Score: 99.75814385674626

# %%
print('Error:')

print('Mean Absolute Error:',mean_absolute_error(y_test,pred_rd))
print('Mean Squared Error:',mean_squared_error(y_test,pred_rd))
print('Root Mean Square Error:',np.sqrt(mean_squared_error(y_test,pred_rd)))
# Out:
# Error:
# Mean Absolute Error: 0.005430174841354621
# Mean Squared Error: 4.250652159700302e-05
# Root Mean Square Error: 0.006519702569673176

# %%
plt.figure(figsize=(8,6))
plt.scatter(x=y_test, y=pred_rd, color='r')
plt.plot(y_test,y_test, color='b')
plt.xlabel('Actual Happiness Score',fontsize=14)
plt.ylabel('Predicted Happiness Score',fontsize=14)
plt.title('Ridge Regression',fontsize=18)
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
from sklearn.linear_model import LinearRegression
lm = LinearRegression()
lm.fit(x_train, y_train)
lm.score(x_train, y_train)
pred_linear = lm.predict(x_test)

lms = r2_score(y_test,pred_linear)
print('R2 Score:',lms*100)

lmscore = cross_val_score(lm,x,y,cv=5)
lmc = lmscore.mean() 
print('Cross Val Score:',lmc*100)
# Out:
# R2 Score: 99.99689235042756
# Cross Val Score: 99.75802437153793

# %%
print('Error:')

print('Mean Absolute Error:',mean_absolute_error(y_test,pred_linear))
print('Mean Squared Error:',mean_squared_error(y_test,pred_linear))
print('Root Mean Square Error:',np.sqrt(mean_squared_error(y_test,pred_linear)))
# Out:
# Error:
# Mean Absolute Error: 0.005431274358984481
# Mean Squared Error: 4.253957150669782e-05
# Root Mean Square Error: 0.006522236695083813

# %%
plt.figure(figsize=(8,6))
plt.scatter(x=y_test, y=pred_linear, color='r')
plt.plot(y_test,y_test, color='b')
plt.xlabel('Actual Happiness Score',fontsize=14)
plt.ylabel('Predicted Happiness Score',fontsize=14)
plt.title('Linear Regression',fontsize=18)
plt.show()

# %% [markdown]
# ## Decision Tree Regression

# %%
from sklearn.tree import DecisionTreeRegressor

parameters = {'criterion':['mse', 'friedman_mse', 'mae'], 'splitter':['best', 'random']}
dt =DecisionTreeRegressor()
clf = GridSearchCV(dt,parameters)
clf.fit(x_train,y_train)

print(clf.best_params_)
# Out:
# {'criterion': 'mse', 'splitter': 'random'}

# %%
dt = DecisionTreeRegressor(criterion='mse', splitter='random')
dt.fit(x_train, y_train)
dt.score(x_train, y_train)
pred_decision = dt.predict(x_test)

dts = r2_score(y_test,pred_decision)
print('R2 Score:',dts*100)

dtscore = cross_val_score(dt,x,y,cv=5)
dtc = dtscore.mean() 
print('Cross Val Score:',dtc*100)
# Out:
# R2 Score: 76.21788813373875
# Cross Val Score: -1119.0857305368627

# %%
print('Error:')

print('Mean Absolute Error:',mean_absolute_error(y_test,pred_decision))
print('Mean Squared Error:',mean_squared_error(y_test,pred_decision))
print('Root Mean Square Error:',np.sqrt(mean_squared_error(y_test,pred_decision)))
# Out:
# Error:
# Mean Absolute Error: 0.45071875000000017
# Mean Squared Error: 0.32554534375000016
# Root Mean Square Error: 0.5705658101831902

# %%
plt.figure(figsize=(8,6))
plt.scatter(x=y_test, y=pred_decision, color='r')
plt.plot(y_test,y_test, color='b')
plt.xlabel('Actual Happiness Score',fontsize=14)
plt.ylabel('Predicted Happiness Score',fontsize=14)
plt.title('Decision Tree Regression',fontsize=18)
plt.show()

# %% [markdown]
# ## Random Forest Regression

# %%
from sklearn.ensemble import RandomForestRegressor

parameters = {'criterion':['mse', 'friedman_mse', 'mae']} #, 'n_estimators': [100,300,500]
rf = RandomForestRegressor()
clf = GridSearchCV(rf,parameters)
clf.fit(x_train,y_train)

print(clf.best_params_)
# Out:
# {'criterion': 'mae'}

# %%
rf = RandomForestRegressor(criterion='mae', n_estimators = 300)
rf.fit(x_train, y_train)
rf.score(x_train, y_train)
pred_random = rf.predict(x_test)

rfs = r2_score(y_test,pred_random)
print('R2 Score:',rfs*100)

rfscore = cross_val_score(rf,x,y,cv=5)
rfc = rfscore.mean() 
print('Cross Val Score:',rfc*100)
# Out:
# R2 Score: 88.57909965454884
# Cross Val Score: -322.0661805244377

# %%
print('Error:')

print('Mean Absolute Error:',mean_absolute_error(y_test,pred_random))
print('Mean Squared Error:',mean_squared_error(y_test,pred_random))
print('Root Mean Square Error:',np.sqrt(mean_squared_error(y_test,pred_random)))
# Out:
# Error:
# Mean Absolute Error: 0.298514791666666
# Mean Squared Error: 0.15633686990468681
# Root Mean Square Error: 0.3953945749560644

# %%
plt.figure(figsize=(8,6))
plt.scatter(x=y_test, y=pred_random, color='r')
plt.plot(y_test,y_test, color='b')
plt.xlabel('Actual Happiness Score',fontsize=14)
plt.ylabel('Predicted Happiness Score',fontsize=14)
plt.title('Random Forest Regression',fontsize=18)
plt.show()

# %% [markdown]
# ## Support Vector Machine Regression

# %%
from sklearn.svm import SVR

parameters = { 'gamma': ['auto', 'scale']}
sv = SVR()
clf = GridSearchCV(sv,parameters)
clf.fit(x_train,y_train)

print(clf.best_params_)
# Out:
# {'gamma': 'auto'}

# %% [markdown]
# 'kernel':['linear', 'poly', 'rbf', 'sigmoid'],

# %%
sv = SVR(kernel = 'linear', gamma = 'auto')
sv.fit(x_train, y_train)
sv.score(x_train, y_train)
pred_vector = sv.predict(x_test)

svs = r2_score(y_test,pred_vector)
print('R2 Score:',svs*100)

svscore = cross_val_score(sv,x,y,cv=5)
svc = svscore.mean() 
print('Cross Val Score:',svc*100)
# Out:
# R2 Score: 99.62514363234479
# Cross Val Score: 86.71056407531316

# %%
print('Error:')

print('Mean Absolute Error:',mean_absolute_error(y_test,pred_vector))
print('Mean Squared Error:',mean_squared_error(y_test,pred_vector))
print('Root Mean Square Error:',np.sqrt(mean_squared_error(y_test,pred_vector)))
# Out:
# Error:
# Mean Absolute Error: 0.06739912310657135
# Mean Squared Error: 0.0051312829470924306
# Root Mean Square Error: 0.0716329738813937

# %%
plt.figure(figsize=(8,6))
plt.scatter(x=y_test, y=pred_vector, color='r')
plt.plot(y_test,y_test, color='b')
plt.xlabel('Actual Happiness Score',fontsize=14)
plt.ylabel('Predicted Happiness Score',fontsize=14)
plt.title('Decision Tree Regression',fontsize=18)
plt.show()

# %% [markdown]
# ### Picking the best model

# %%
models = pd.DataFrame({
    'Model': ['Lasso Regression', 'Ridge Regression', 'Linear Regression', 
              'Decision Tree Regression','Random Forest Regression', 'Support Vector Machine Regression'],
    'R2 Score': [lss, rds, lms, dts, rfs, svs],
    'Cross Val Score': [lsc, rdc, lmc, dtc, rfc, svc]})
models.sort_values(by='R2 Score', ascending=False)
# Out:
#                                Model  R2 Score  Cross Val Score
# 0                   Lasso Regression  0.999970         0.997574
# 1                   Ridge Regression  0.999969         0.997581
# 2                  Linear Regression  0.999969         0.997580
# 5  Support Vector Machine Regression  0.996251         0.867106
# 4           Random Forest Regression  0.885791        -3.220662
# 3           Decision Tree Regression  0.762179       -11.190857

# %% [markdown]
# Lasso Regression has maximum R2 score hence its the best model

# %% [markdown]
# ## Saving the best model

# %%
import pickle

filename = 'happiness.pkl'
pickle.dump(ls, open(filename, 'wb'))

# Load the model from disk
loaded_model = pickle.load(open(filename, 'rb'))

loaded_model.predict(test_x)
